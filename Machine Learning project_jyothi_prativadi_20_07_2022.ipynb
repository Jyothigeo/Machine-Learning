# %%
import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt   
import seaborn as sns
# %matplotlib inline 
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("Election_Data_project.csv" )

# %%
df.head()
# Out:
#    Unnamed: 0    vote  age  economic.cond.national  economic.cond.household  \
# 0           1  Labour   43                       3                        3
# 1           2  Labour   36                       4                        4
# 2           3  Labour   35                       4                        4
# 3           4  Labour   24                       4                        2
# 4           5  Labour   41                       2                        2
#
#    Blair  Hague  Europe  political.knowledge  gender
# 0      4      1       2                    2  female
# 1      4      4       5                    2    male
# 2      5      2       3                    2    male
# 3      2      1       4                    0  female
# 4      1      1       6                    2    male

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#      vote  age  economic.cond.national  economic.cond.household  Blair  Hague  \
# 0  Labour   43                       3                        3      4      1
# 1  Labour   36                       4                        4      4      4
# 2  Labour   35                       4                        4      5      2
# 3  Labour   24                       4                        2      2      1
# 4  Labour   41                       2                        2      1      1
#
#    Europe  political.knowledge  gender
# 0       2                    2  female
# 1       5                    2    male
# 2       3                    2    male
# 3       4                    0  female
# 4       6                    2    male

# %%
df.shape
# Out:
# (1525, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vote                     1525 non-null   object
#  1   age                      1525 non-null   int64
#  2   economic.cond.national   1525 non-null   int64
#  3   economic.cond.household  1525 non-null   int64
#  4   Blair                    1525 non-null   int64
#  5   Hague                    1525 non-null   int64
#  6   Europe                   1525 non-null   int64
#  7   political.knowledge      1525 non-null   int64
#  8   gender                   1525 non-null   object
# dtypes: int64(7), object(2)
# memory usage: 107.4+ KB

# %%
df.describe(include="all").T
# Out:
#                           count unique     top  freq       mean        std  \
# vote                       1525      2  Labour  1063        NaN        NaN
# age                      1525.0    NaN     NaN   NaN  54.182295  15.711209
# economic.cond.national   1525.0    NaN     NaN   NaN   3.245902   0.880969
# economic.cond.household  1525.0    NaN     NaN   NaN   3.140328   0.929951
# Blair                    1525.0    NaN     NaN   NaN   3.334426   1.174824
# Hague                    1525.0    NaN     NaN   NaN   2.746885   1.230703
# Europe                   1525.0    NaN     NaN   NaN   6.728525   3.297538
# political.knowledge      1525.0    NaN     NaN   NaN   1.542295   1.083315
# gender                     1525      2  female   812        NaN        NaN
#
#                           min   25%   50%   75%   max
# vote                      NaN   NaN   NaN   NaN   NaN
# age                      24.0  41.0  53.0  67.0  93.0
# economic.cond.national    1.0   3.0   3.0   4.0   5.0
# ...

# %%
df.skew()
# Out:
# age                        0.144621
# economic.cond.national    -0.240453
# economic.cond.household   -0.149552
# Blair                     -0.535419
# Hague                      0.152100
# Europe                    -0.135947
# political.knowledge       -0.426838
# dtype: float64

# %%
df.var()
# Out:
# age                        246.842075
# economic.cond.national       0.776107
# economic.cond.household      0.864810
# Blair                        1.380212
# Hague                        1.514631
# Europe                      10.873759
# political.knowledge          1.173571
# dtype: float64

# %%
df['vote'].value_counts()
# Out:
# Labour          1063
# Conservative     462
# Name: vote, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# female    812
# male      713
# Name: gender, dtype: int64

# %%
df['Blair'].value_counts()
# Out:
# 4    836
# 2    438
# 5    153
# 1     97
# 3      1
# Name: Blair, dtype: int64

# %%
df['Hague'].value_counts()
# Out:
# 2    624
# 4    558
# 1    233
# 5     73
# 3     37
# Name: Hague, dtype: int64

# %%
df['Europe'].value_counts()
# Out:
# 11    338
# 6     209
# 3     129
# 4     127
# 5     124
# 8     112
# 9     111
# 1     109
# 10    101
# 7      86
# 2      79
# Name: Europe, dtype: int64

# %%
df['political.knowledge'].value_counts()
# Out:
# 2    782
# 0    455
# 3    250
# 1     38
# Name: political.knowledge, dtype: int64

# %%
df['economic.cond.national'].value_counts()
# Out:
# 3    607
# 4    542
# 2    257
# 5     82
# 1     37
# Name: economic.cond.national, dtype: int64

# %%
df['economic.cond.household'].value_counts()
# Out:
# 3    648
# 4    440
# 2    280
# 5     92
# 1     65
# Name: economic.cond.household, dtype: int64

# %%
## Univariate Analysis(continuos variable)

# %%
sns.histplot(df['age'] , kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.boxplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
## Univariate Analysis(categorical variable)

# %%
sns.countplot(df['vote'])
# Out:
# <AxesSubplot:xlabel='vote', ylabel='count'>

# %%
sns.countplot(df['gender'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(df['Blair'])
# Out:
# <AxesSubplot:xlabel='Blair', ylabel='count'>

# %%
sns.countplot(df['Hague'])
# Out:
# <AxesSubplot:xlabel='Hague', ylabel='count'>

# %%
sns.countplot(df['Europe'])
# Out:
# <AxesSubplot:xlabel='Europe', ylabel='count'>

# %%
sns.countplot(df['political.knowledge'])
# Out:
# <AxesSubplot:xlabel='political.knowledge', ylabel='count'>

# %%
sns.countplot(df['economic.cond.national'])
# Out:
# <AxesSubplot:xlabel='economic.cond.national', ylabel='count'>

# %%
sns.countplot(df['economic.cond.household'])
# Out:
# <AxesSubplot:xlabel='economic.cond.household', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
df.boxplot(vert=0)
# Out:
# <AxesSubplot:>

# %%
##Bivariate Analysis

# %%
cat=["Blair","Hague","Europe","political.knowledge","economic.cond.national","economic.cond.household"]

# %%
for i in cat:
    df[i]=df[i].astype("object")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vote                     1525 non-null   object
#  1   age                      1525 non-null   int64
#  2   economic.cond.national   1525 non-null   object
#  3   economic.cond.household  1525 non-null   object
#  4   Blair                    1525 non-null   object
#  5   Hague                    1525 non-null   object
#  6   Europe                   1525 non-null   object
#  7   political.knowledge      1525 non-null   object
#  8   gender                   1525 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 107.4+ KB

# %%
cat=[]
num=[]
for i in df.columns:
    if df[i].dtype=="object":
        cat.append(i)
    else:
        num.append(i)
print(cat) 
print(num)
# Out:
# ['vote', 'gender']
# ['age', 'economic.cond.national', 'economic.cond.household', 'Blair', 'Hague', 'Europe', 'political.knowledge']

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        print(column.upper(),': ',df[column].nunique())
        print(df[column].value_counts().sort_values())
        print('\n')
# Out:
# VOTE :  2
# Conservative     462
# Labour          1063
# Name: vote, dtype: int64
#
#
# ECONOMIC.COND.NATIONAL :  5
# 1     37
# 5     82
# 2    257
# 4    542
# 3    607
# Name: economic.cond.national, dtype: int64
#
#
# ECONOMIC.COND.HOUSEHOLD :  5
# 1     65
# 5     92
# 2    280
# 4    440
# 3    648
# Name: economic.cond.household, dtype: int64
#
#
# BLAIR :  5
# 3      1
# 1     97
# 5    153
# 2    438
# 4    836
# Name: Blair, dtype: int64
#
#
# HAGUE :  5
# 3     37
# 5     73
# 1    233
# 4    558
# 2    624
# Name: Hague, dtype: int64
#
#
# EUROPE :  11
# 2      79
# 7      86
# 10    101
# 1     109
# 9     111
# 8     112
# 5     124
# 4     127
# 3     129
# 6     209
# 11    338
# Name: Europe, dtype: int64
#
#
# POLITICAL.KNOWLEDGE :  4
# 1     38
# 3    250
# 0    455
# 2    782
# Name: political.knowledge, dtype: int64
#
#
# GENDER :  2
# male      713
# female    812
# Name: gender, dtype: int64

# %%
df.isnull().sum()
# Out:
# vote                       0
# age                        0
# economic.cond.national     0
# economic.cond.household    0
# Blair                      0
# Hague                      0
# Europe                     0
# political.knowledge        0
# gender                     0
# dtype: int64

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

df[dups]
# Out:
# Number of duplicate rows = 8
#               vote  age economic.cond.national economic.cond.household Blair  \
# 67          Labour   35                      4                       4     5
# 626         Labour   39                      3                       4     4
# 870         Labour   38                      2                       4     2
# 983   Conservative   74                      4                       3     2
# 1154  Conservative   53                      3                       4     2
# 1236        Labour   36                      3                       3     2
# 1244        Labour   29                      4                       4     4
# 1438        Labour   40                      4                       3     4
#
#      Hague Europe political.knowledge  gender
# 67       2      3                   2    male
# 626      2      5                   2    male
# 870      2      4                   3    male
# 983      4      8                   2  female
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

df[dups]
# Out:
# Number of duplicate rows = 0
# Empty DataFrame
# Columns: [vote, age, economic.cond.national, economic.cond.household, Blair, Hague, Europe, political.knowledge, gender]
# Index: []

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        print(column.upper(),': ',df[column].nunique())
        print(df[column].value_counts().sort_values())
        print('\n')
# Out:
# VOTE :  2
# Conservative     460
# Labour          1057
# Name: vote, dtype: int64
#
#
# GENDER :  2
# male      709
# female    808
# Name: gender, dtype: int64

# %%
sns.boxplot(df["vote"],df['age'])
# Out:
# <AxesSubplot:xlabel='vote', ylabel='age'>

# %%
sns.boxplot(df["gender"],df['age'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %%
plt.figure(figsize=(8,5))
sns.stripplot(df["vote"], df['age'], jitter=True) 
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.stripplot(df["gender"], df['age'], jitter=True) 
plt.show()

# %%
sns.countplot(x='Blair', hue='vote', data=df)
# Out:
# <AxesSubplot:xlabel='Blair', ylabel='count'>

# %%
sns.countplot(x='Hague', hue='vote', data=df)
# Out:
# <AxesSubplot:xlabel='Hague', ylabel='count'>

# %%
sns.countplot(x='Europe', hue='vote', data=df)
# Out:
# <AxesSubplot:xlabel='Europe', ylabel='count'>

# %%
df.head()
# Out:
#      vote  age economic.cond.national economic.cond.household Blair Hague  \
# 0  Labour   43                      3                       3     4     1
# 1  Labour   36                      4                       4     4     4
# 2  Labour   35                      4                       4     5     2
# 3  Labour   24                      4                       2     2     1
# 4  Labour   41                      2                       2     1     1
#
#   Europe political.knowledge  gender
# 0      2                   2  female
# 1      5                   2    male
# 2      3                   2    male
# 3      4                   0  female
# 4      6                   2    male

# %% [markdown]
# # Encoding

# %%
cat1=['gender']

# %%
df =pd.get_dummies(df, columns=cat1,drop_first=True)

# %%
df.head()
# Out:
#      vote  age economic.cond.national economic.cond.household Blair Hague  \
# 0  Labour   43                      3                       3     4     1
# 1  Labour   36                      4                       4     4     4
# 2  Labour   35                      4                       4     5     2
# 3  Labour   24                      4                       2     2     1
# 4  Labour   41                      2                       2     1     1
#
#   Europe political.knowledge  gender_male
# 0      2                   2            0
# 1      5                   2            1
# 2      3                   2            1
# 3      4                   0            0
# 4      6                   2            1

# %%
df.groupby(["vote"]).count()
# Out:
#                age  economic.cond.national  economic.cond.household  Blair  \
# vote
# Conservative   460                     460                      460    460
# Labour        1057                    1057                     1057   1057
#
#               Hague  Europe  political.knowledge  gender_male
# vote
# Conservative    460     460                  460          460
# Labour         1057    1057                 1057         1057

# %%
df.vote.value_counts(normalize=True)
# Out:
# Labour          0.69677
# Conservative    0.30323
# Name: vote, dtype: float64

# %%
## Test Train Split

# %%
from sklearn.model_selection import train_test_split
X = df.drop('vote',axis=1)
y = df.vote
test_size = 0.30

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=1)

# %%
X_train
# Out:
#       age  economic.cond.national  economic.cond.household  Blair  Hague  \
# 991    34                       2                        4      1      4
# 1274   40                       4                        3      4      4
# 649    61                       4                        3      4      4
# 677    47                       3                        3      4      2
# 538    44                       5                        3      4      2
# ...   ...                     ...                      ...    ...    ...
# 717    52                       3                        3      4      1
# 908    43                       3                        4      2      2
# 1100   74                       4                        3      5      4
# 236    31                       3                        3      2      3
# 1065   89                       3                        5      4      2
#
#       Europe  political.knowledge  gender_male
# ...

# %%
print('X_train',X_train.shape)
print('X_test',X_test.shape)
print('y_train',y_train.shape)
print('y_test',y_test.shape)
# Out:
# X_train (1061, 8)
# X_test (456, 8)
# y_train (1061,)
# y_test (456,)

# %%
y
# Out:
# 0             Labour
# 1             Labour
# 2             Labour
# 3             Labour
# 4             Labour
#             ...
# 1520    Conservative
# 1521    Conservative
# 1522          Labour
# 1523    Conservative
# 1524    Conservative
# Name: vote, Length: 1517, dtype: object

# %% [markdown]
# ## Simple logistic regression(no scaling)

# %%
from sklearn.linear_model import LogisticRegression
LR_model_S = LogisticRegression()
LR_model_S.fit(X_train, y_train)
y_predict_test_LRS = LR_model_S.predict(X_test)
y_predict_train_LRS = LR_model_S.predict(X_train)

# %%
LRS_modelscore_train = LR_model_S.score(X_train, y_train)
print('Accuracy Score is ',LRS_modelscore)
# Out:
# Accuracy Score is  0.8341187558906692

# %%
LRS_modelscore_test = LR_model_S.score(X_test, y_test)
print('Accuracy Score is ',LRS_modelscore_test)
# Out:
# Accuracy Score is  0.8245614035087719

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y_train, y_predict_train_LRS),'\n')
print('Classification Report','\n',metrics.classification_report(y_train, y_predict_train_LRS))
# Out:
# Confusion Matrix
#  [[199 108]
#  [ 68 686]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.75      0.65      0.69       307
#       Labour       0.86      0.91      0.89       754
#
#     accuracy                           0.83      1061
#    macro avg       0.80      0.78      0.79      1061
# weighted avg       0.83      0.83      0.83      1061

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y_test, y_predict_test_LRS),'\n')
print('Classification Report','\n',metrics.classification_report(y_test, y_predict_test_LRS))
# Out:
# Confusion Matrix
#  [[109  44]
#  [ 36 267]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.75      0.71      0.73       153
#       Labour       0.86      0.88      0.87       303
#
#     accuracy                           0.82       456
#    macro avg       0.81      0.80      0.80       456
# weighted avg       0.82      0.82      0.82       456

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
LRS_metrics=metrics.classification_report(y_test, y_predict_test_LRS,output_dict=True)
df=pd.DataFrame(LRS_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
LRS_test_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
LRS_test_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
LRS_test_f1=round(df.loc["Labour"][2],2)


print ('LRS_test_precision ',LRS_test_precision)
print ('LRS_test_recall ',LRS_test_recall)
print ('LRS_test_f1 ',LRS_test_f1)
# Out:
# LRS_test_precision  0.86
# LRS_test_recall  0.88
# LRS_test_f1  0.87

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
LRS_metrics=metrics.classification_report(y_train, y_predict_train_LRS,output_dict=True)
df=pd.DataFrame(LRS_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
LRS_train_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
LRS_train_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
LRS_train_f1=round(df.loc["Labour"][2],2)


print ('LRS_train_precision ',LRS_train_precision)
print ('LRS_train_recall ',LRS_train_recall)
print ('LRS_train_f1 ',LRS_train_f1)
# Out:
# LRS_train_precision  0.86
# LRS_train_recall  0.91
# LRS_train_f1  0.89

# %%
sns.heatmap(confusion_matrix(y_train,y_predict_train_LRS),annot=True, fmt='d', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## logistic regression with hyperparameters(no scaling)

# %%
model = LogisticRegression(solver='newton-cg',max_iter=10000,penalty='none',verbose=True,n_jobs=2)
model.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 out of   1 | elapsed:    1.2s finished
# LogisticRegression(max_iter=10000, n_jobs=2, penalty='none', solver='newton-cg',
#                    verbose=True)

# %%
ytrain_predict = model.predict(X_train)
ytest_predict = model.predict(X_test)

# %%
ytest_predict_prob=model.predict_proba(X_test)
pd.DataFrame(ytest_predict_prob).head()
# Out:
#           0         1
# 0  0.424284  0.575716
# 1  0.148426  0.851574
# 2  0.007187  0.992813
# 3  0.836350  0.163650
# 4  0.068407  0.931593

# %%
# Accuracy - Training Data
model.score(X_train, y_train)
# Out:
# 0.8312912346842601

# %%
# Accuracy - Test Data
model.score(X_test, y_test)
# Out:
# 0.8355263157894737

# %%
confusion_matrix(y_train, ytrain_predict)
# Out:
# array([[196, 111],
#        [ 68, 686]], dtype=int64)

# %%
print(classification_report(y_train, ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.74      0.64      0.69       307
#       Labour       0.86      0.91      0.88       754
#
#     accuracy                           0.83      1061
#    macro avg       0.80      0.77      0.79      1061
# weighted avg       0.83      0.83      0.83      1061

# %% [markdown]
# # Logistic Regression GridSearch

# %%
grid={'penalty':['l2','none'],
      'solver':['saga','lbfgs''newton-cg'],
      'tol':[0.0001,0.00001]}

# %%
LR_model = LogisticRegression(max_iter=10000,n_jobs=2)

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
grid_search = GridSearchCV(estimator = LR_model, param_grid = grid, cv = 3,n_jobs=-1,scoring='f1')

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=LogisticRegression(max_iter=10000, n_jobs=2),
#              n_jobs=-1,
#              param_grid={'penalty': ['l2', 'none'],
#                          'solver': ['saga', 'lbfgsnewton-cg'],
#                          'tol': [0.0001, 1e-05]},
#              scoring='f1')

# %%
print(grid_search.best_params_,'\n')
print(grid_search.best_estimator_)
# Out:
# {'penalty': 'l2', 'solver': 'saga', 'tol': 0.0001}
#
# LogisticRegression(max_iter=10000, n_jobs=2, solver='saga')

# %%
best_model = grid_search.best_estimator_

# %%
ytrain_predict = best_model.predict(X_train)
ytest_predict = best_model.predict(X_test)

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y_train, ytrain_predict),'\n')
print('Classification Report','\n',metrics.classification_report(y_train, ytrain_predict))
# Out:
# Confusion Matrix
#  [[197 110]
#  [ 69 685]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.74      0.64      0.69       307
#       Labour       0.86      0.91      0.88       754
#
#     accuracy                           0.83      1061
#    macro avg       0.80      0.78      0.79      1061
# weighted avg       0.83      0.83      0.83      1061

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y_test, ytest_predict),'\n')
print('Classification Report','\n',metrics.classification_report(y_test, ytest_predict))
# Out:
# Confusion Matrix
#  [[108  45]
#  [ 35 268]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.76      0.71      0.73       153
#       Labour       0.86      0.88      0.87       303
#
#     accuracy                           0.82       456
#    macro avg       0.81      0.80      0.80       456
# weighted avg       0.82      0.82      0.82       456

# %%
solver_list = ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga']
params = dict(solver=solver_list)
log_reg = LogisticRegression(C=1, n_jobs=-1, random_state=1)
clf = GridSearchCV(log_reg, params, cv=5)
clf.fit(X_train, y_train)
scores = clf.cv_results_['mean_test_score']

for score, solver in zip(scores, solver_list):
    print(f"  {solver} {score:.3f}" )
# Out:
#   liblinear 0.829
#   newton-cg 0.828
#   lbfgs 0.828
#   sag 0.828
#   saga 0.828

# %%
# predict the probabilities of 0's and 1's. this is done on the test data 
ytest_predict
ytest_predict_prob=best_model.predict_proba(X_test)
ytest_predict_prob
pd.DataFrame(ytest_predict_prob).head()
# Out:
#           0         1
# 0  0.415655  0.584345
# 1  0.153597  0.846403
# 2  0.006851  0.993149
# 3  0.835151  0.164849
# 4  0.073081  0.926919

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = best_model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
LR_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % LR_train_auc)
# calculate roc curve
LR_train_fpr, LR_train_tpr, LR_trainthresholds = roc_curve(y_train, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(LR_train_fpr, LR_train_tpr)
# Out:
# AUC: 0.889

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = best_model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
LR_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % LR_test_auc)
# calculate roc curve
LR_test_fpr, LR_test_tpr, LR_testthresholds = roc_curve(y_test, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(LR_test_fpr, LR_test_tpr)
# Out:
# AUC: 0.874

# %% [markdown]
# # LDA without scaling(LDA scaling performed at row 280)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
clf = LinearDiscriminantAnalysis()

# %%
LDA_model=clf.fit(X_train,y_train)

# %%
# Predict it
pred_class_train= LDA_model.predict(X_train)
pred_class_test = LDA_model.predict(X_test)

# %%
print(classification_report(y_train, pred_class_train))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.74      0.65      0.69       307
#       Labour       0.86      0.91      0.89       754
#
#     accuracy                           0.83      1061
#    macro avg       0.80      0.78      0.79      1061
# weighted avg       0.83      0.83      0.83      1061

# %%
print(classification_report(y_test, pred_class_test))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.77      0.73      0.74       153
#       Labour       0.86      0.89      0.88       303
#
#     accuracy                           0.83       456
#    macro avg       0.82      0.81      0.81       456
# weighted avg       0.83      0.83      0.83       456

# %%
LDA_GridSearch

# %%
grid_LDA={
      'solver':['svd','lsqr''eigen'],
      'tol':[0.0001,0.00001]}

# %%
LDA_model = LinearDiscriminantAnalysis()

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
grid_search = GridSearchCV(estimator = LDA_model, param_grid = grid_LDA, cv = 3,n_jobs=-1,scoring='f1')

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=LinearDiscriminantAnalysis(), n_jobs=-1,
#              param_grid={'solver': ['svd', 'lsqreigen'],
#                          'tol': [0.0001, 1e-05]},
#              scoring='f1')

# %%
print(grid_search.best_params_,'\n')
print(grid_search.best_estimator_)
# Out:
# {'solver': 'svd', 'tol': 0.0001}
#
# LinearDiscriminantAnalysis()

# %%
best_model = grid_search.best_estimator_

# %%
ytrain_predict = best_model.predict(X_train)
ytest_predict = best_model.predict(X_test)

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y_train, y_predict_train),'\n')
print('Classification Report','\n',metrics.classification_report(y_train, y_predict_train))
# Out:
# Confusion Matrix
#  [[199 108]
#  [ 68 686]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.75      0.65      0.69       307
#       Labour       0.86      0.91      0.89       754
#
#     accuracy                           0.83      1061
#    macro avg       0.80      0.78      0.79      1061
# weighted avg       0.83      0.83      0.83      1061

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y_test, y_predict_test),'\n')
print('Classification Report','\n',metrics.classification_report(y_test, y_predict_test))
# Out:
# Confusion Matrix
#  [[109  44]
#  [ 36 267]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.75      0.71      0.73       153
#       Labour       0.86      0.88      0.87       303
#
#     accuracy                           0.82       456
#    macro avg       0.81      0.80      0.80       456
# weighted avg       0.82      0.82      0.82       456

# %%
from sklearn.preprocessing import scale
X_scaledtrain=scale(X_train)

# %%
X_scaledtrain
# Out:
# array([[-1.29671043, -1.45558149,  0.90210034, ...,  1.33208942,
#          0.45223123, -0.93695043],
#        [-0.91033745,  0.87730667, -0.16374427, ..., -0.20215599,
#         -1.4075259 ,  1.06729232],
#        [ 0.44196795,  0.87730667, -0.16374427, ...,  0.10469309,
#          0.45223123, -0.93695043],
#        ...,
#        [ 1.2791094 ,  0.87730667, -0.16374427, ...,  1.33208942,
#         -1.4075259 , -0.93695043],
#        [-1.48989691, -0.28913741, -0.16374427, ..., -0.20215599,
#         -1.4075259 , -0.93695043],
#        [ 2.24504183, -0.28913741,  1.96794496, ..., -1.7364014 ,
#         -1.4075259 ,  1.06729232]])

# %%
model2=clf.fit(X_scaledtrain,y_train)
model2
# Out:
# LinearDiscriminantAnalysis()

# %%
pred_class2 = model2.predict(scale(X_test))

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, pred_class2))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.69      0.65      0.67       130
#       Labour       0.87      0.88      0.87       328
#
#     accuracy                           0.82       458
#    macro avg       0.78      0.77      0.77       458
# weighted avg       0.81      0.82      0.82       458

# %% [markdown]
# # Naive Base Model

# %%
from sklearn.naive_bayes import GaussianNB # using Gaussian algorithm from Naive Bayes

# creatw the model
Naive_model = GaussianNB()

Naive_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_train_predict = Naive_model.predict(X_train)
y_test_predict=Naive_model.predict(X_test)
model_score_train = Naive_model.score(X_train, y_train) 
model_score_test = Naive_model.score(X_test, y_test) 
## Accuracy
print(model_score_train)
print(metrics.confusion_matrix(y_train, y_train_predict))          ## confusion_matrix
print(metrics.classification_report(y_train, y_train_predict))     ## classification_report
# Out:
# 0.8350612629594723
# [[211  96]
#  [ 79 675]]
#               precision    recall  f1-score   support
#
# Conservative       0.73      0.69      0.71       307
#       Labour       0.88      0.90      0.89       754
#
#     accuracy                           0.84      1061
#    macro avg       0.80      0.79      0.80      1061
# weighted avg       0.83      0.84      0.83      1061

# %%
print(model_score_test)
print(metrics.confusion_matrix(y_test, y_test_predict))          ## confusion_matrix
print(metrics.classification_report(y_test, y_test_predict))     ## classification_report
# Out:
# 0.8223684210526315
# [[112  41]
#  [ 40 263]]
#               precision    recall  f1-score   support
#
# Conservative       0.74      0.73      0.73       153
#       Labour       0.87      0.87      0.87       303
#
#     accuracy                           0.82       456
#    macro avg       0.80      0.80      0.80       456
# weighted avg       0.82      0.82      0.82       456

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = Naive_model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
NB_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % NB_train_auc)
# calculate roc curve
NB_train_fpr, NB_train_tpr, NB_trainthresholds = roc_curve(y_train, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(NB_train_fpr, NB_train_tpr)
# Out:
# AUC: 0.888

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = Naive_model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
NB_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % NB_test_auc)
# calculate roc curve
NB_test_fpr, NB_test_tpr, NB_testthresholds = roc_curve(y_test, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(NB_test_fpr, NB_test_tpr)
# Out:
# AUC: 0.876

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
NB_metrics=classification_report(y_test, y_test_predict,output_dict=True)
df=pd.DataFrame(NB_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
NB_test_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
NB_test_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
NB_test_f1=round(df.loc["Labour"][2],2)


print ('NB_test_precision ',NB_test_precision)
print ('NB_test_recall ',NB_test_recall)
print ('NB_test_f1 ',NB_test_f1)
# Out:
# NB_test_precision  0.87
# NB_test_recall  0.87
# NB_test_f1  0.87

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
NB_metrics=classification_report(y_train, y_train_predict,output_dict=True)
df=pd.DataFrame(NB_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
NB_train_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
NB_train_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
NB_train_f1=round(df.loc["Labour"][2],2)


print ('NB_train_precision ',NB_train_precision)
print ('NB_train_recall ',NB_train_recall)
print ('NB_train_f1 ',NB_train_f1)
# Out:
# NB_train_precision  0.88
# NB_train_recall  0.9
# NB_train_f1  0.89

# %% [markdown]
# # Descision Tree Model(Simple model)

# %%
print('X_train',X_train.shape)
print('X_test',X_test.shape)
print('y_train',y_train.shape)
print('y_test',y_test.shape)
# Out:
# X_train (1061, 8)
# X_test (456, 8)
# y_train (1061,)
# y_test (456,)

# %%
from sklearn.tree import DecisionTreeClassifier
DTree_Model = DecisionTreeClassifier(criterion = 'gini', random_state=1)
DTree_Model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
DT_modelscore_train=DTree_Model.score(X_train, y_train)
DT_modelscore_test=DTree_Model.score(X_test, y_test)
print(DTree_Model.score(X_train, y_train))
print(DTree_Model.score(X_test, y_test))
# Out:
# 1.0
# 0.7960526315789473

# %%
ytrainpredict = DTree_Model.predict(X_train)
ytestpredict = DTree_Model.predict(X_test)

# %%
print(metrics.classification_report(y_train, ytrainpredict))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       1.00      1.00      1.00       307
#       Labour       1.00      1.00      1.00       754
#
#     accuracy                           1.00      1061
#    macro avg       1.00      1.00      1.00      1061
# weighted avg       1.00      1.00      1.00      1061

# %%
print(metrics.classification_report(y_test, ytestpredict))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.71      0.67      0.69       153
#       Labour       0.84      0.86      0.85       303
#
#     accuracy                           0.80       456
#    macro avg       0.77      0.76      0.77       456
# weighted avg       0.79      0.80      0.79       456

# %% [markdown]
# # Descision Tree Model(Grid Search)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'criterion': ['gini','entropy'],
    'max_depth': [10,20,30,50],
    'min_samples_leaf': [50,100,150], 
    'min_samples_split': [150,300,450],
}

DTree_Model = DecisionTreeClassifier(random_state=1)

grid_search = GridSearchCV(estimator = DTree_Model, param_grid = param_grid, cv = 10)

# %%
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)
best_grid = grid_search.best_estimator_
best_grid
# Out:
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 50, 'min_samples_split': 150}
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=50, min_samples_split=150,
#                        random_state=1)

# %%
from sklearn import tree
train_char_label = ['No', 'Yes']
Election_Tree_File = open('credit_tree.dot','w')
dot_data = tree.export_graphviz(best_grid, out_file=Election_Tree_File, feature_names = list(X_train), class_names = list(train_char_label))
Election_Tree_File.close()

# %%
# importance of features in the tree building ( The importance of a feature is computed as the 
#(normalized) total reduction of the criterion brought by that feature. It is also known as the Gini importance )

print (pd.DataFrame(best_grid.feature_importances_, columns = ["Imp"], index = X_train.columns))
# Out:
#                               Imp
# age                      0.005371
# economic.cond.national   0.000000
# economic.cond.household  0.016016
# Blair                    0.291641
# Hague                    0.516263
# Europe                   0.139037
# political.knowledge      0.030280
# gender_male              0.001392

# %%
ytrain_predict = best_grid.predict(X_train)
ytest_predict = best_grid.predict(X_test)

# %%
# predict the probabilities of 0's and 1's. this is done on the test data 
ytest_predict
ytest_predict_prob=best_grid.predict_proba(X_test)
ytest_predict_prob
pd.DataFrame(ytest_predict_prob).head()
# Out:
#           0         1
# 0  0.481928  0.518072
# 1  0.170732  0.829268
# 2  0.000000  1.000000
# 3  0.801370  0.198630
# 4  0.550000  0.450000

# %%
cart_train_acc=best_grid.score(X_train,y_train) 
cart_train_acc
# Out:
# 0.8086710650329878

# %%
cart_test_acc=best_grid.score(X_test,y_test) 
cart_test_acc
# Out:
# 0.7894736842105263

# %%
print(metrics.classification_report(y_train, ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.67      0.66      0.67       307
#       Labour       0.86      0.87      0.87       754
#
#     accuracy                           0.81      1061
#    macro avg       0.77      0.76      0.77      1061
# weighted avg       0.81      0.81      0.81      1061

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, ytest_predict))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.69      0.68      0.68       153
#       Labour       0.84      0.84      0.84       303
#
#     accuracy                           0.79       456
#    macro avg       0.76      0.76      0.76       456
# weighted avg       0.79      0.79      0.79       456

# %%
# predict probabilities
probs = best_grid.predict_proba(X_train)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
cart_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % cart_train_auc)

# calculate roc curve. roc_curve(actual, predicted)
cart_train_fpr, cart_train_tpr, cart_train_thresholds = roc_curve(y_train, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(cart_train_fpr, cart_train_tpr)
# Out:
# AUC: 0.869

# %%
# predict probabilities
probs = best_grid.predict_proba(X_test)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
cart_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % cart_test_auc)

# calculate roc curve. roc_curve(actual, predicted)
cart_test_fpr, cart_test_tpr, cart_test_thresholds = roc_curve(y_test, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(cart_test_fpr, cart_test_tpr)
# Out:
# AUC: 0.854

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
cart_metrics=classification_report(y_train, ytrain_predict,output_dict=True)
df=pd.DataFrame(cart_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
cart_train_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
cart_train_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
cart_train_f1=round(df.loc["Labour"][2],2)


print ('cart_train_precision ',cart_train_precision)
print ('cart_train_recall ',cart_train_recall)
print ('cart_train_f1 ',cart_train_f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [203], in <cell line: 2>()
#       1 # below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
# ----> 2 cart_metrics=classification_report(y_train, ytrain_predict,output_dict=True)
#       3 df=pd.DataFrame(cart_metrics).transpose()
#       5 # The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
#       6 # 2 decimal digit
#
# NameError: name 'classification_report' is not defined

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
cart_metrics=classification_report(y_test, ytest_predict,output_dict=True)
df=pd.DataFrame(cart_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
cart_test_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
cart_test_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
cart_test_f1=round(df.loc["Labour"][2],2)


print ('cart_test_precision ',cart_test_precision)
print ('cart_test_recall ',cart_test_recall)
print ('cart_test_f1 ',cart_test_f1)

# %% [markdown]
# # Random Forest for Bagging(simple)

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clfRF=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clfRF.fit(X_train,y_train)

y_pred_test=clfRF.predict(X_test)
y_pred_train=clfRF.predict(X_train)
model_scoreRF_test = clfRF.score(X_test, y_test)
model_scoreRF_train = clfRF.score(X_train, y_train)

# %%
print(model_scoreRF_test)

print(metrics.confusion_matrix(y_test, y_pred_test))
# Out:
# 0.8289473684210527
# [[103  50]
#  [ 28 275]]

# %%
print(model_scoreRF_train)
y_pred_train=clfRF.predict(X_train)
print(metrics.confusion_matrix(y_train, y_pred_train))
# Out:
# 1.0
# [[307   0]
#  [  0 754]]

# %% [markdown]
# # Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

bgcl = BaggingClassifier(base_estimator=clfRF,n_estimators=50,random_state=1) #BaggingClassifier(n_estimators=50,random_state=1)

bgcl = bgcl.fit(X_train, y_train)

# %%
y_predict_test = bgcl.predict(X_test)

print(bgcl.score(X_test , y_test))
print(metrics.confusion_matrix(y_test, y_predict_test))
# Out:
# 0.831140350877193
# [[103  50]
#  [ 27 276]]

# %%
bgcl_score_test=bgcl.score(X_test , y_test)
bgcl_score_test
# Out:
# 0.831140350877193

# %%
bgcl_score_train=bgcl.score(X_train , y_train)
bgcl_score_train
# Out:
# 0.9641847313854854

# %%
y_predict_train = bgcl.predict(X_train)
print(bgcl.score(X_train , y_train))
print(metrics.confusion_matrix(y_train, y_predict_train))
# Out:
# 0.9641847313854854
# [[276  31]
#  [  7 747]]

# %%
print(metrics.classification_report(y_train, y_predict_train))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.98      0.90      0.94       307
#       Labour       0.96      0.99      0.98       754
#
#     accuracy                           0.96      1061
#    macro avg       0.97      0.94      0.96      1061
# weighted avg       0.96      0.96      0.96      1061

# %%
print(metrics.classification_report(y_test, y_predict_test))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.79      0.67      0.73       153
#       Labour       0.85      0.91      0.88       303
#
#     accuracy                           0.83       456
#    macro avg       0.82      0.79      0.80       456
# weighted avg       0.83      0.83      0.83       456

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
bgcl_metrics=classification_report(y_train, y_predict_train,output_dict=True)
df=pd.DataFrame(bgcl_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
bgcl_train_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
bgcl_train_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
bgcl_train_f1=round(df.loc["Labour"][2],2)


print ('bgcl_train_precision ',bgcl_train_precision)
print ('bgcl_train_recall ',bgcl_train_recall)
print ('bgcl_train_f1 ',bgcl_train_f1)
# Out:
# bgcl_train_precision  1.0
# bgcl_train_recall  1.0
# bgcl_train_f1  1.0

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
bgcl_metrics=classification_report(y_test, y_predict_test,output_dict=True)
df=pd.DataFrame(bgcl_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
bgcl_test_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
bgcl_test_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
bgcl_test_f1=round(df.loc["Labour"][2],2)


print ('bgcl_test_precision ',bgcl_test_precision)
print ('bgcl_test_recall ',bgcl_test_recall)
print ('bgcl_test_f1 ',bgcl_test_f1)
# Out:
# bgcl_test_precision  0.85
# bgcl_test_recall  0.91
# bgcl_test_f1  0.88

# %% [markdown]
# # Bagging classifier Grid Search

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    
    'max_features': [4, 6],
    'max_samples': [50, 100],    
    'n_estimators': [101,301, 501]
}

bgcl_GS = BaggingClassifier()

grid_search = GridSearchCV(estimator = bgcl_GS, param_grid = param_grid, cv = 3)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=BaggingClassifier(),
#              param_grid={'max_features': [4, 6], 'max_samples': [50, 100],
#                          'n_estimators': [101, 301, 501]})

# %%
grid_search.best_params_
# Out:
# {'max_features': 6, 'max_samples': 50, 'n_estimators': 501}

# %%
best_grid = grid_search.best_estimator_

# %%
ytrain_predict = best_grid.predict(X_train)

# %%
ytest_predict = best_grid.predict(X_test)

# %%
print(best_grid.score(X_test , y_test))
print(metrics.confusion_matrix(y_test, ytest_predict))
# Out:
# 0.8245614035087719
# [[ 96  57]
#  [ 23 280]]

# %%
print(best_grid.score(X_train , y_train))
print(metrics.confusion_matrix(y_train, ytrain_predict))
# Out:
# 0.8426013195098964
# [[179 128]
#  [ 39 715]]

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(metrics.classification_report(y_train, ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.82      0.58      0.68       307
#       Labour       0.85      0.95      0.90       754
#
#     accuracy                           0.84      1061
#    macro avg       0.83      0.77      0.79      1061
# weighted avg       0.84      0.84      0.83      1061

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(metrics.classification_report(y_test, ytest_predict))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.81      0.63      0.71       153
#       Labour       0.83      0.92      0.88       303
#
#     accuracy                           0.82       456
#    macro avg       0.82      0.78      0.79       456
# weighted avg       0.82      0.82      0.82       456

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
bag_metrics=classification_report(y_test, ytest_predict,output_dict=True)
df=pd.DataFrame(bag_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
bag_test_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
bag_test_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
bag_test_f1=round(df.loc["Labour"][2],2)


print ('bag_test_precision ',bag_test_precision)
print ('bag_test_recall ',bag_test_recall)
print ('bag_test_f1 ',bag_test_f1)
# Out:
# bag_test_precision  0.84
# bag_test_recall  0.93
# bag_test_f1  0.88

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
bag_metrics=classification_report(y_train, ytrain_predict,output_dict=True)
df=pd.DataFrame(bag_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
bag_train_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
bag_train_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
bag_train_f1=round(df.loc["Labour"][2],2)


print ('bag_train_precision ',bag_train_precision)
print ('bag_train_recall ',bag_train_recall)
print ('bag_train_f1 ',bag_train_f1)
# Out:
# bag_train_precision  0.88
# bag_train_recall  0.95
# bag_train_f1  0.92

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = best_grid.predict_proba(X_train)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
bag_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % bag_train_auc)

# calculate roc curve. roc_curve(actual, predicted)
bag_train_fpr, bag_train_tpr, bag_train_thresholds = roc_curve(y_train, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(bag_train_fpr, bag_train_tpr)
# Out:
# AUC: 0.916

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = best_grid.predict_proba(X_test)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
bag_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % bag_test_auc)

# calculate roc curve. roc_curve(actual, predicted)
bag_test_fpr, bag_test_tpr, bag_test_thresholds = roc_curve(y_test, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(bag_test_fpr, bag_test_tpr)
# Out:
# AUC: 0.883

# %% [markdown]
# ## Random Forest Grid search

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [7, 10],
    'max_features': [4, 6],
    'min_samples_leaf': [50, 100],
    'min_samples_split': [150, 300],
    'n_estimators': [301, 501]
}

rfcl = RandomForestClassifier()

grid_search = GridSearchCV(estimator = rfcl, param_grid = param_grid, cv = 3)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [7, 10], 'max_features': [4, 6],
#                          'min_samples_leaf': [50, 100],
#                          'min_samples_split': [150, 300],
#                          'n_estimators': [301, 501]})

# %%
grid_search.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': 6,
#  'min_samples_leaf': 100,
#  'min_samples_split': 150,
#  'n_estimators': 301}

# %%
best_grid = grid_search.best_estimator_

# %%
ytrain_predict = best_grid.predict(X_train)

# %%
ytest_predict = best_grid.predict(X_test)

# %%
x=pd.DataFrame(best_grid.feature_importances_*100,index=X_train.columns).sort_values(by=0,ascending=False)
plt.figure(figsize=(12,7))
sns.barplot(x[0],x.index,palette='dark')
plt.xlabel('Feature Importance in %')
plt.ylabel('Features')
plt.title('Feature Importance using RF')
plt.show()

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(metrics.classification_report(y_train, ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.73      0.48      0.58       307
#       Labour       0.81      0.93      0.87       754
#
#     accuracy                           0.80      1061
#    macro avg       0.77      0.71      0.72      1061
# weighted avg       0.79      0.80      0.79      1061

# %%
print(best_grid.score(X_train , y_train))
print(metrics.confusion_matrix(y_train, ytrain_predict))
# Out:
# 0.7992459943449576
# [[148 159]
#  [ 54 700]]

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(metrics.classification_report(y_test, ytest_predict))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.78      0.50      0.61       153
#       Labour       0.79      0.93      0.85       303
#
#     accuracy                           0.79       456
#    macro avg       0.78      0.71      0.73       456
# weighted avg       0.78      0.79      0.77       456

# %%
print(best_grid.score(X_test , y_test))
print(metrics.confusion_matrix(y_test, ytest_predict))
# Out:
# 0.7850877192982456
# [[ 76  77]
#  [ 21 282]]

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
RF_metrics=classification_report(y_test, ytest_predict,output_dict=True)
df=pd.DataFrame(RF_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
RF_test_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
RF_test_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
RF_test_f1=round(df.loc["Labour"][2],2)


print ('RF_test_precision ',RF_test_precision)
print ('RF_test_recall ',RF_test_recall)
print ('RF_test_f1 ',RF_test_f1)
# Out:
# RF_test_precision  0.79
# RF_test_recall  0.93
# RF_test_f1  0.85

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
RF_metrics=classification_report(y_train, ytrain_predict,output_dict=True)
df=pd.DataFrame(RF_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
RF_train_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
RF_train_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
RF_train_f1=round(df.loc["Labour"][2],2)


print ('RF_train_precision ',RF_train_precision)
print ('RF_train_recall ',RF_train_recall)
print ('RF_train_f1 ',RF_train_f1)
# Out:
# RF_train_precision  0.81
# RF_train_recall  0.93
# RF_train_f1  0.87

# %% [markdown]
# ## Boosting

# %% [markdown]
# ## Ada Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier

clfADB = AdaBoostClassifier(n_estimators=100)
clfADB.fit(X_train,y_train)
y_pred_test=clfADB.predict(X_test)
model_scoreADB_test = clfADB.score(X_test, y_test)
print(model_scoreADB_test)
print(metrics.confusion_matrix(y_test, y_pred_test))
# Out:
# 0.8135964912280702
# [[103  50]
#  [ 35 268]]

# %%
y_pred_train=clfADB.predict(X_train)
model_scoreADB_train = clfADB.score(X_train, y_train)
print(model_scoreADB_train)
print(metrics.confusion_matrix(y_train, y_pred_train))
# Out:
# 0.8501413760603205
# [[214  93]
#  [ 66 688]]

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(metrics.classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.75      0.67      0.71       153
#       Labour       0.84      0.88      0.86       303
#
#     accuracy                           0.81       456
#    macro avg       0.79      0.78      0.79       456
# weighted avg       0.81      0.81      0.81       456

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(metrics.classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.76      0.70      0.73       307
#       Labour       0.88      0.91      0.90       754
#
#     accuracy                           0.85      1061
#    macro avg       0.82      0.80      0.81      1061
# weighted avg       0.85      0.85      0.85      1061

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
AdaB_metrics=classification_report(y_test, y_pred_test,output_dict=True)
df=pd.DataFrame(AdaB_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
AdaB_test_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
AdaB_test_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
AdaB_test_f1=round(df.loc["Labour"][2],2)


print ('AdaB_test_precision ',AdaB_test_precision)
print ('AdaB_test_recall ',AdaB_test_recall)
print ('AdaB_test_f1 ',AdaB_test_f1)
# Out:
# AdaB_test_precision  0.84
# AdaB_test_recall  0.88
# AdaB_test_f1  0.86

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
AdaB_metrics=classification_report(y_train, y_pred_train,output_dict=True)
df=pd.DataFrame(AdaB_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
AdaB_train_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
AdaB_train_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
AdaB_train_f1=round(df.loc["Labour"][2],2)

print ('AdaB_train_precision ',AdaB_train_precision)
print ('AdaB_train_recall ',AdaB_train_recall)
print ('AdaB_train_f1 ',AdaB_train_f1)
# Out:
# AdaB_train_precision  0.88
# AdaB_train_recall  0.91
# AdaB_train_f1  0.9

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = clfADB.predict_proba(X_train)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
ada_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % ada_train_auc)

# calculate roc curve. roc_curve(actual, predicted)
ada_train_fpr, ada_train_tpr, ada_train_thresholds = roc_curve(y_train, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(ada_train_fpr, ada_train_tpr)
# Out:
# AUC: 0.915

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = clfADB.predict_proba(X_test)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
ada_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % ada_test_auc)

# calculate roc curve. roc_curve(actual, predicted)
ada_test_fpr, ada_test_tpr, ada_test_thresholds = roc_curve(y_test, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(ada_test_fpr, ada_test_tpr)
# Out:
# AUC: 0.877

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbcl = GradientBoostingClassifier(n_estimators = 50,random_state=1)
gbcl = gbcl.fit(X_train, y_train)

# %%
y_predict_test = gbcl.predict(X_test)
print(gbcl.score(X_test, y_test))
print(metrics.confusion_matrix(y_test, y_predict_test))
# Out:
# 0.8289473684210527
# [[103  50]
#  [ 28 275]]

# %%
gbcl_score_test=gbcl.score(X_test, y_test)
gbcl_score_test
# Out:
# 0.8289473684210527

# %%
gbcl_score_train=gbcl.score(X_train, y_train)
gbcl_score_train
# Out:
# 0.8803016022620169

# %%
y_predict_train = gbcl.predict(X_train)
print(gbcl.score(X_train, y_train))
print(metrics.confusion_matrix(y_train, y_predict_train))
# Out:
# 0.8803016022620169
# [[226  81]
#  [ 46 708]]

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(metrics.classification_report(y_train, y_predict_train))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.98      0.90      0.94       307
#       Labour       0.96      0.99      0.98       754
#
#     accuracy                           0.96      1061
#    macro avg       0.97      0.94      0.96      1061
# weighted avg       0.96      0.96      0.96      1061

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(metrics.classification_report(y_test, y_predict_test))
# Out:
#               precision    recall  f1-score   support
#
# Conservative       0.79      0.67      0.73       153
#       Labour       0.85      0.91      0.88       303
#
#     accuracy                           0.83       456
#    macro avg       0.82      0.79      0.80       456
# weighted avg       0.83      0.83      0.83       456

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
GradB_metrics=classification_report(y_test, y_predict_test,output_dict=True)
df=pd.DataFrame(GradB_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
GradB_test_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
GradB_test_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
GradB_test_f1=round(df.loc["Labour"][2],2)


print ('GradB_test_precision ',GradB_test_precision)
print ('GradB_test_recall ',GradB_test_recall)
print ('GradB_test_f1 ',GradB_test_f1)
# Out:
# GradB_test_precision  0.85
# GradB_test_recall  0.91
# GradB_test_f1  0.88

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
GradB_metrics=classification_report(y_train, y_predict_train,output_dict=True)
df=pd.DataFrame(GradB_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
GradB_train_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
GradB_train_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
GradB_train_f1=round(df.loc["Labour"][2],2)


print ('GradB_train_precision ',GradB_train_precision)
print ('GradB_train_recall ',GradB_train_recall)
print ('GradB_train_f1 ',GradB_train_f1)
# Out:
# GradB_train_precision  0.9
# GradB_train_recall  0.94
# GradB_train_f1  0.92

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = gbcl.predict_proba(X_test)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
gbcl_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % gbcl_test_auc)

# calculate roc curve. roc_curve(actual, predicted)
gbcl_test_fpr, gbcl_test_tpr, gbcl_test_thresholds = roc_curve(y_test, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(gbcl_test_fpr, gbcl_test_tpr)
# Out:
# AUC: 0.897

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = gbcl.predict_proba(X_train)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
gbcl_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % gbcl_train_auc)

# calculate roc curve. roc_curve(actual, predicted)
gbcl_train_fpr, gbcl_train_tpr, gbcl_train_thresholds = roc_curve(y_train, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(gbcl_train_fpr, gbcl_train_tpr)
# Out:
# AUC: 0.935

# %% [markdown]
# ## Scaling for (logistic regression,LDA,KNN )

# %%
X[["age"]]=X[["age"]].apply(zscore)

# %%
X
# Out:
#            age  economic.cond.national  economic.cond.household  Blair  Hague  \
# 0    -0.716161                       3                        3      4      1
# 1    -1.162118                       4                        4      4      4
# 2    -1.225827                       4                        4      5      2
# 3    -1.926617                       4                        2      2      1
# 4    -0.843577                       2                        2      1      1
# ...        ...                     ...                      ...    ...    ...
# 1520  0.812836                       5                        3      2      4
# 1521  1.195085                       2                        2      4      4
# 1522 -1.098410                       3                        3      5      4
# 1523  0.430587                       3                        3      1      4
# 1524  1.258794                       2                        3      2      4
#
# ...

# %%
X.var()
# Out:
# age                         1.000660
# economic.cond.national      0.777558
# economic.cond.household     0.866890
# Blair                       1.380089
# Hague                       1.519005
# Europe                     10.883687
# political.knowledge         1.175961
# gender_male                 0.249099
# dtype: float64

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X,y,test_size=0.3, random_state=1)

# %%
print(X1_train.shape)
print(X1_test.shape)
print(y1_train.shape)
print(y1_test.shape)
# Out:
# (1061, 8)
# (456, 8)
# (1061,)
# (456,)

# %%
from sklearn.linear_model import LogisticRegression
LRSmodel_scaled = LogisticRegression()
LRSmodel_scaled.fit(X1_train, y1_train)
y1_scaled_predict_test = LRSmodel_scaled.predict(X1_test)
y1_scaled_predict_train = LRSmodel_scaled.predict(X1_train)

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y1_train,y1_scaled_predict_train ),'\n')
print('Classification Report','\n',metrics.classification_report(y1_train, y1_scaled_predict_train))
# Out:
# Confusion Matrix
#  [[196 111]
#  [ 68 686]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.74      0.64      0.69       307
#       Labour       0.86      0.91      0.88       754
#
#     accuracy                           0.83      1061
#    macro avg       0.80      0.77      0.79      1061
# weighted avg       0.83      0.83      0.83      1061

# %%
model_score = LRSmodel_scaled.score(X1_train, y1_train)
print('Accuracy Score is ',model_score)
# Out:
# Accuracy Score is  0.8312912346842601

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y1_test,y1_scaled_predict_test ),'\n')
print('Classification Report','\n',metrics.classification_report(y1_test, y1_scaled_predict_test))
# Out:
# Confusion Matrix
#  [[112  41]
#  [ 36 267]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.76      0.73      0.74       153
#       Labour       0.87      0.88      0.87       303
#
#     accuracy                           0.83       456
#    macro avg       0.81      0.81      0.81       456
# weighted avg       0.83      0.83      0.83       456

# %%
model_score = LRSmodel_scaled.score(X1_test, y1_test)
print('Accuracy Score is ',model_score)
# Out:
# Accuracy Score is  0.831140350877193

# %%
## Logistic Regression Grid search

# %%
grid={'penalty':['l2','none'],
      'solver':['saga','lbfgs''newton-cg'],
      'tol':[0.0001,0.00001]}

# %%
LR_GS_model = LogisticRegression(max_iter=10000,n_jobs=2)

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
grid_search = GridSearchCV(estimator = LR_GS_model, param_grid = grid, cv = 3,n_jobs=-1,scoring='f1')

# %%
grid_search.fit(X1_train, y1_train)
# Out:
# GridSearchCV(cv=3, estimator=LogisticRegression(max_iter=10000, n_jobs=2),
#              n_jobs=-1,
#              param_grid={'penalty': ['l2', 'none'],
#                          'solver': ['saga', 'lbfgsnewton-cg'],
#                          'tol': [0.0001, 1e-05]},
#              scoring='f1')

# %%
print(grid_search.best_params_,'\n')
print(grid_search.best_estimator_)
# Out:
# {'penalty': 'l2', 'solver': 'saga', 'tol': 0.0001}
#
# LogisticRegression(max_iter=10000, n_jobs=2, solver='saga')

# %%
best_model = grid_search.best_estimator_

# %%
ytrain_predict_LRG = best_model.predict(X1_train)
ytest_predict_LRG = best_model.predict(X1_test)

# %%
LRG_score_test = best_model.score(X1_test, y1_test)
print('Accuracy Score is ',LRG_score_test)
# Out:
# Accuracy Score is  0.8267543859649122

# %%
LRG_score_train = best_model.score(X1_train, y1_train)
print('Accuracy Score is ',LRG_score_train)
# Out:
# Accuracy Score is  0.8369462770970783

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y1_train, ytrain_predict_LRG),'\n')
print('Classification Report','\n',metrics.classification_report(y1_train, ytrain_predict_LRG))
# Out:
# Confusion Matrix
#  [[198 109]
#  [ 64 690]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.76      0.64      0.70       307
#       Labour       0.86      0.92      0.89       754
#
#     accuracy                           0.84      1061
#    macro avg       0.81      0.78      0.79      1061
# weighted avg       0.83      0.84      0.83      1061

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y1_test, ytest_predict_LRG),'\n')
print('Classification Report','\n',metrics.classification_report(y1_test, ytest_predict_LRG))
# Out:
# Confusion Matrix
#  [[110  43]
#  [ 36 267]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.75      0.72      0.74       153
#       Labour       0.86      0.88      0.87       303
#
#     accuracy                           0.83       456
#    macro avg       0.81      0.80      0.80       456
# weighted avg       0.83      0.83      0.83       456

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
LRG_metrics=classification_report(y1_test, ytest_predict_LRG,output_dict=True)
df=pd.DataFrame(LRG_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
LRG_test_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
LRG_test_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
LRG_test_f1=round(df.loc["Labour"][2],2)


print ('LRG_test_precision ',LRG_test_precision)
print ('LRG_test_recall ',LRG_test_recall)
print ('LRG_test_f1 ',LRG_test_f1)
# Out:
# LRG_test_precision  0.86
# LRG_test_recall  0.88
# LRG_test_f1  0.87

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
LRG_metrics=classification_report(y1_train, ytrain_predict_LRG,output_dict=True)
df=pd.DataFrame(LRG_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
LRG_train_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
LRG_train_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
LRG_train_f1=round(df.loc["Labour"][2],2)


print ('LRG_train_precision ',LRG_train_precision)
print ('LRG_train_recall ',LRG_train_recall)
print ('LRG_train_f1 ',LRG_train_f1)
# Out:
# LRG_train_precision  0.86
# LRG_train_recall  0.92
# LRG_train_f1  0.89

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = LRSmodel_scaled.predict_proba(X1_test)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
LRS_test_auc = roc_auc_score(y1_test, probs)
print('AUC: %.3f' % LRS_test_auc)

# calculate roc curve. roc_curve(actual, predicted)
LRS_test_fpr, LRS_test_tpr, LRS_test_thresholds = roc_curve(y1_test, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(LRS_test_fpr, LRS_test_tpr)
# Out:
# AUC: 0.883

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = LRSmodel_scaled.predict_proba(X1_train)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
LRS_train_auc = roc_auc_score(y1_train, probs)
print('AUC: %.3f' % LRS_train_auc)

# calculate roc curve. roc_curve(actual, predicted)
LRS_train_fpr, LRS_train_tpr, LRS_train_thresholds = roc_curve(y1_train, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(LRS_train_fpr, LRS_train_tpr)
# Out:
# AUC: 0.890

# %% [markdown]
# ## Linear Discriminant Analysis LDA (on scale data)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
clf = LinearDiscriminantAnalysis()

# %%
LDA_model_scaled=clf.fit(X1_train,y1_train)

# %%
# Predict it
LDApred_class_train= LDA_model_scaled.predict(X1_train)
LDApred_class_test = LDA_model_scaled.predict(X1_test)

# %%
LDA_score_test = LDA_model_scaled.score(X1_test, y1_test)
print('Accuracy Score is ',LDA_score_test)
# Out:
# Accuracy Score is  0.8333333333333334

# %%
LDA_score_train = LDA_model_scaled.score(X1_train, y1_train)
print('Accuracy Score is ',LDA_score_train)
# Out:
# Accuracy Score is  0.8341187558906692

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y1_train,LDApred_class_train ),'\n')
print('Classification Report','\n',metrics.classification_report(y1_train, LDApred_class_train))
# Out:
# Confusion Matrix
#  [[200 107]
#  [ 69 685]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.74      0.65      0.69       307
#       Labour       0.86      0.91      0.89       754
#
#     accuracy                           0.83      1061
#    macro avg       0.80      0.78      0.79      1061
# weighted avg       0.83      0.83      0.83      1061

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y1_test,LDApred_class_test ),'\n')
print('Classification Report','\n',metrics.classification_report(y1_test, LDApred_class_test))
# Out:
# Confusion Matrix
#  [[111  42]
#  [ 34 269]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.77      0.73      0.74       153
#       Labour       0.86      0.89      0.88       303
#
#     accuracy                           0.83       456
#    macro avg       0.82      0.81      0.81       456
# weighted avg       0.83      0.83      0.83       456

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
LDA_metrics=classification_report(y1_test, LDApred_class_test,output_dict=True)
df=pd.DataFrame(LDA_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
LDA_test_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
LDA_test_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
LDA_test_f1=round(df.loc["Labour"][2],2)


print ('LDA_test_precision ',LDA_test_precision)
print ('LDA_test_recall ',LDA_test_recall)
print ('LDA_test_f1 ',LDA_test_f1)
# Out:
# LDA_test_precision  0.86
# LDA_test_recall  0.89
# LDA_test_f1  0.88

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
LDA_metrics=classification_report(y1_train, LDApred_class_train,output_dict=True)
df=pd.DataFrame(LDA_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
LDA_train_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
LDA_train_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
LDA_train_f1=round(df.loc["Labour"][2],2)


print ('LDA_train_precision ',LDA_train_precision)
print ('LDA_train_recall ',LDA_train_recall)
print ('LDA_train_f1 ',LDA_train_f1)
# Out:
# LDA_train_precision  0.86
# LDA_train_recall  0.91
# LDA_train_f1  0.89

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = clf.predict_proba(X1_test)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
LDA_test_auc = roc_auc_score(y1_test, probs)
print('AUC: %.3f' % LDA_test_auc)

# calculate roc curve. roc_curve(actual, predicted)
LDA_test_fpr, LDA_test_tpr, LDA_test_thresholds = roc_curve(y1_test, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(LDA_test_fpr, LDA_test_tpr)
# Out:
# AUC: 0.888

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = clf.predict_proba(X1_train)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
LDA_train_auc = roc_auc_score(y1_train, probs)
print('AUC: %.3f' % LDA_train_auc)

# calculate roc curve. roc_curve(actual, predicted)
LDA_train_fpr, LDA_train_tpr, LDA_train_thresholds = roc_curve(y1_train, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(LDA_train_fpr, LDA_train_tpr)
# Out:
# AUC: 0.889

# %% [markdown]
# ## KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier()

# %%
KNN.fit(X1_train, y1_train)
# Out:
# KNeighborsClassifier()

# %%
predicted_labels_test = KNN.predict(X1_test)
KNN_score_test=KNN.score(X1_test, y1_test)
KNN_score_test
# Out:
# 0.8267543859649122

# %%
predicted_labels_train = KNN.predict(X1_train)
KNN_score_train=KNN.score(X1_train, y1_train)
KNN_score_train
# Out:
# 0.8586239396795476

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y1_train, predicted_labels_train),'\n')
print('Classification Report','\n',metrics.classification_report(y1_train, predicted_labels_train))
# Out:
# Confusion Matrix
#  [[220  87]
#  [ 71 683]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.76      0.72      0.74       307
#       Labour       0.89      0.91      0.90       754
#
#     accuracy                           0.85      1061
#    macro avg       0.82      0.81      0.82      1061
# weighted avg       0.85      0.85      0.85      1061

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y1_test, predicted_labels_test),'\n')
print('Classification Report','\n',metrics.classification_report(y1_test, predicted_labels_test))
# Out:
# Confusion Matrix
#  [[105  48]
#  [ 38 265]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.73      0.69      0.71       153
#       Labour       0.85      0.87      0.86       303
#
#     accuracy                           0.81       456
#    macro avg       0.79      0.78      0.78       456
# weighted avg       0.81      0.81      0.81       456

# %%
print('Confusion Matrix','\n',metrics.confusion_matrix(y1_train, predicted_labels_train),'\n')
print('Classification Report','\n',metrics.classification_report(y1_train, predicted_labels_train))
# Out:
# Confusion Matrix
#  [[307   0]
#  [  0 754]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       1.00      1.00      1.00       307
#       Labour       1.00      1.00      1.00       754
#
#     accuracy                           1.00      1061
#    macro avg       1.00      1.00      1.00      1061
# weighted avg       1.00      1.00      1.00      1061

# %% [markdown]
# # KNN Model(Tuning)

# %%
# empty list that will hold accuracy scores
ac_scores = []

# perform accuracy metrics for values from 1,3,5....19
for k in range(1,20,2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X1_train, y1_train)
    # evaluate test accuracy
    scores = knn.score(X1_test, y1_test)
    ac_scores.append(scores)

# changing to misclassification error
MCE = [1 - x for x in ac_scores]  
MCE
# Out:
# [0.22587719298245612,
#  0.20394736842105265,
#  0.1885964912280702,
#  0.17105263157894735,
#  0.1885964912280702,
#  0.19736842105263153,
#  0.19517543859649122,
#  0.20175438596491224,
#  0.20175438596491224,
#  0.19956140350877194]

# %%
ac_scores
# Out:
# [0.7741228070175439,
#  0.7960526315789473,
#  0.8114035087719298,
#  0.8289473684210527,
#  0.8114035087719298,
#  0.8026315789473685,
#  0.8048245614035088,
#  0.7982456140350878,
#  0.7982456140350878,
#  0.8004385964912281]

# %%
#Plot misclassification error vs k (with k value on X-axis) using matplotli
import matplotlib.pyplot as plt
# plot misclassification error vs k
plt.plot(range(1,20,2), MCE)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Misclassification Error')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN_tune = KNeighborsClassifier(n_neighbors= 7 , weights = 'distance' )

# %%
KNN_tune.fit(X1_train, y1_train)
# Out:
# KNeighborsClassifier(n_neighbors=7, weights='distance')

# %%
predicted_labels_train = KNN_tune.predict(X1_train)
KNN_tune.score(X1_train, y1_train)
# Out:
# 1.0

# %%
predicted_labels_test = KNN_tune.predict(X1_test)
KNN_tune.score(X1_test, y1_test)
# Out:
# 0.8114035087719298

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y1_test, predicted_labels_test),'\n')
print('Classification Report','\n',metrics.classification_report(y1_test, predicted_labels_test))
# Out:
# Confusion Matrix
#  [[ 98  55]
#  [ 40 263]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.71      0.64      0.67       153
#       Labour       0.83      0.87      0.85       303
#
#     accuracy                           0.79       456
#    macro avg       0.77      0.75      0.76       456
# weighted avg       0.79      0.79      0.79       456

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y1_train, predicted_labels_train),'\n')
print('Classification Report','\n',metrics.classification_report(y1_train, predicted_labels_train))
# Out:
# Confusion Matrix
#  [[307   0]
#  [  0 754]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       1.00      1.00      1.00       307
#       Labour       1.00      1.00      1.00       754
#
#     accuracy                           1.00      1061
#    macro avg       1.00      1.00      1.00      1061
# weighted avg       1.00      1.00      1.00      1061

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
KNN_metrics=classification_report(y1_train, predicted_labels_train,output_dict=True)
df=pd.DataFrame(KNN_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
KNN_train_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
KNN_train_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
KNN_train_f1=round(df.loc["Labour"][2],2)


print ('KNN_train_precision ',KNN_train_precision)
print ('KNN_train_recall ',KNN_train_recall)
print ('KNN_train_f1 ',KNN_train_f1)
# Out:
# KNN_train_precision  1.0
# KNN_train_recall  1.0
# KNN_train_f1  1.0

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
KNN_metrics=classification_report(y1_test, predicted_labels_test,output_dict=True)
df=pd.DataFrame(KNN_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
KNN_test_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
KNN_test_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
KNN_test_f1=round(df.loc["Labour"][2],2)


print ('KNN_test_precision ',KNN_test_precision)
print ('KNN_test_recall ',KNN_test_recall)
print ('KNN_test_f1 ',KNN_test_f1)
# Out:
# KNN_test_precision  0.83
# KNN_test_recall  0.87
# KNN_test_f1  0.85

# %%
# below code is creating a classification report and storing in rf_metric. this is then used to convert into dataframe
KNN_metrics=classification_report(y1_train, predicted_labels_train,output_dict=True)
df=pd.DataFrame(KNN_metrics).transpose()

# The code is accessing the index values (1 -positives) of the dataframe index-1, first value(0) which is precision and with
# 2 decimal digit
KNN_train_precision=round(df.loc["Labour"][0],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, second value(1) which is recall and with
# 2 decimal digit
KNN_train_recall=round(df.loc["Labour"][1],2)

# The code is accessing the index values (1 -positives) of the dataframe index-1, third value(2) which is precision and with
# 2 decimal digit
KNN_train_f1=round(df.loc["Labour"][2],2)


print ('KNN_train_precision ',KNN_train_precision)
print ('KNN_train_recall ',KNN_train_recall)
print ('KNN_train_f1 ',KNN_train_f1)
# Out:
# KNN_train_precision  1.0
# KNN_train_recall  1.0
# KNN_train_f1  1.0

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = KNN.predict_proba(X1_train)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
KNN_train_auc = roc_auc_score(y1_train, probs)
print('AUC: %.3f' % KNN_train_auc)

# calculate roc curve. roc_curve(actual, predicted)
KNN_train_fpr, KNN_train_tpr, KNN_train_thresholds = roc_curve(y1_train, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(KNN_train_fpr, KNN_train_tpr)
# Out:
# AUC: 0.927

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
# predict probabilities
probs = KNN.predict_proba(X1_test)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# calculate AUC. roc_auc_score(actual, predicted)
KNN_test_auc = roc_auc_score(y1_test, probs)
print('AUC: %.3f' % KNN_test_auc)

# calculate roc curve. roc_curve(actual, predicted)
KNN_test_fpr, KNN_test_tpr, KNN_test_thresholds = roc_curve(y1_test, probs,pos_label='Labour')
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(KNN_test_fpr, KNN_test_tpr)
# Out:
# AUC: 0.865

# %% [markdown]
# # Smote on Naive Bayes

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state=2)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

# %%
y_train_res.value_counts()
# Out:
# Conservative    754
# Labour          754
# Name: vote, dtype: int64

# %%
NB_SM_model = GaussianNB()
NB_SM_model.fit(X_train_res, y_train_res)
# Out:
# GaussianNB()

# %%
y_train_predict = NB_SM_model.predict(X_train_res)
model_score = NB_SM_model.score(X_train_res, y_train_res)
print(model_score)
print(metrics.confusion_matrix(y_train_res, y_train_predict))
print(metrics.classification_report(y_train_res ,y_train_predict))
# Out:
# 0.8328912466843501
# [[628 126]
#  [126 628]]
#               precision    recall  f1-score   support
#
# Conservative       0.83      0.83      0.83       754
#       Labour       0.83      0.83      0.83       754
#
#     accuracy                           0.83      1508
#    macro avg       0.83      0.83      0.83      1508
# weighted avg       0.83      0.83      0.83      1508

# %%
## Performance Matrix on test data set
y_test_predict = NB_SM_model.predict(X_test)
model_score = NB_SM_model.score(X_test, y_test)
print(model_score)
print(metrics.confusion_matrix(y_test, y_test_predict))
print(metrics.classification_report(y_test, y_test_predict))
# Out:
# 0.8070175438596491
# [[119  34]
#  [ 54 249]]
#               precision    recall  f1-score   support
#
# Conservative       0.69      0.78      0.73       153
#       Labour       0.88      0.82      0.85       303
#
#     accuracy                           0.81       456
#    macro avg       0.78      0.80      0.79       456
# weighted avg       0.82      0.81      0.81       456

# %% [markdown]
# ## Smote KNN model

# %%
sm = SMOTE(random_state=2)
X_train_res, y_train_res = sm.fit_resample(X1_train, y1_train)

# %%
y_train_res.value_counts()
# Out:
# Conservative    754
# Labour          754
# Name: vote, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN_tune_smote = KNeighborsClassifier(n_neighbors= 7 , weights = 'distance' )

# %%
KNN_tune_smote.fit(X_train_res, y_train_res)
# Out:
# KNeighborsClassifier(n_neighbors=7, weights='distance')

# %%
predicted_labels_train = KNN_tune_smote.predict(X1_train_res)
KNN_tune_smote.score(X_train_res, y_train_res)
# Out:
# 1.0

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y_train_res, predicted_labels_train),'\n')
print('Classification Report','\n',metrics.classification_report(y_train_res, predicted_labels_train))
# Out:
# Confusion Matrix
#  [[754   0]
#  [  0 754]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       1.00      1.00      1.00       754
#       Labour       1.00      1.00      1.00       754
#
#     accuracy                           1.00      1508
#    macro avg       1.00      1.00      1.00      1508
# weighted avg       1.00      1.00      1.00      1508

# %%
predicted_labels_test = KNN_tune_smote.predict(X1_test)
KNN_tune_smote.score(X1_test, y1_test)
# Out:
# 0.793859649122807

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y1_test, predicted_labels_test),'\n')
print('Classification Report','\n',metrics.classification_report(y1_test, predicted_labels_test))
# Out:
# Confusion Matrix
#  [[120  33]
#  [ 61 242]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.66      0.78      0.72       153
#       Labour       0.88      0.80      0.84       303
#
#     accuracy                           0.79       456
#    macro avg       0.77      0.79      0.78       456
# weighted avg       0.81      0.79      0.80       456

# %% [markdown]
# # Smote Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LRSmodel_smote = LogisticRegression()
LRSmodel_smote.fit(X_train_res, y_train_res)
y1_smote_predict_test = LRSmodel_smote.predict(X_test)
y1_smote_predict_train = LRSmodel_smote.predict(X_train_res)

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y_train_res,y1_smote_predict_train ),'\n')
print('Classification Report','\n',metrics.classification_report(y_train_res, y1_smote_predict_train))
# Out:
# Confusion Matrix
#  [[628 126]
#  [128 626]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.83      0.83      0.83       754
#       Labour       0.83      0.83      0.83       754
#
#     accuracy                           0.83      1508
#    macro avg       0.83      0.83      0.83      1508
# weighted avg       0.83      0.83      0.83      1508

# %%
from sklearn import metrics
print('Confusion Matrix','\n',metrics.confusion_matrix(y_test,y1_smote_predict_test ),'\n')
print('Classification Report','\n',metrics.classification_report(y_test, y1_smote_predict_test))
# Out:
# Confusion Matrix
#  [[153   0]
#  [302   1]]
#
# Classification Report
#                precision    recall  f1-score   support
#
# Conservative       0.34      1.00      0.50       153
#       Labour       1.00      0.00      0.01       303
#
#     accuracy                           0.34       456
#    macro avg       0.67      0.50      0.25       456
# weighted avg       0.78      0.34      0.17       456

# %% [markdown]
# ## Comparing all models

# %%
index=['Accuracy', 'AUC', 'Recall','Precision','F1 Score']
data = pd.DataFrame({'LRG_Train':[LRG_score_train,LRS_train_auc,LRG_train_recall,LRG_train_precision,LRG_train_f1],
        'LRG_Test':[LRG_score_test,LRS_test_auc,LRG_test_recall,LRG_test_precision,LRG_test_f1],
       'LDA_Train':[LDA_score_train,LDA_train_auc,LDA_train_recall,LDA_train_precision,LDA_train_f1],
        'LDA_Test':[LDA_score_test,LDA_test_auc,LDA_test_recall,LDA_test_precision,LDA_test_f1],
       'Neural Network Train':[KNN_score_train,KNN_train_auc,KNN_train_recall,KNN_train_precision,KNN_train_f1],
        'Neural Network Test':[KNN_score_test,KNN_test_auc,KNN_test_recall,KNN_test_precision,KNN_test_f1],
          'Naive_bayes_Train':[model_score_train,NB_train_auc,NB_train_recall,NB_train_precision,NB_train_f1],
        'Naive_bayes_Test':[model_score_test,NB_test_auc,NB_test_recall,NB_test_precision,NB_test_f1],        
         'Bagging_train':[bgcl_score_train,bag_train_auc,bag_train_recall,bag_train_precision,bag_train_f1],
        'Bagging_test':[bgcl_score_test,bag_test_auc,bag_test_recall,bag_test_precision,bag_test_f1],           
         'Boosting_train':[model_scoreADB_train,gbcl_train_auc,AdaB_train_recall,AdaB_train_precision,AdaB_train_f1],
        'Boosting_test':[model_scoreADB_test,gbcl_test_auc,AdaB_test_recall,AdaB_test_precision,AdaB_test_f1],           
                               
                    
                    
                    },index=index)
round(data,2)
# Out:
#            LRG_Train  LRG_Test  LDA_Train  LDA_Test  Neural Network Train  \
# Accuracy        0.84      0.83       0.83      0.83                  0.86
# AUC             0.89      0.88       0.89      0.89                  0.92
# Recall          0.92      0.88       0.91      0.89                  1.00
# Precision       0.86      0.86       0.86      0.86                  1.00
# F1 Score        0.89      0.87       0.89      0.88                  1.00
#
#            Neural Network Test  Naive_bayes_Train  Naive_bayes_Test  \
# Accuracy                  0.81               0.84              0.82
# AUC                       0.85               0.89              0.88
# Recall                    0.91               0.90              0.87
# Precision                 0.84               0.88              0.87
# F1 Score                  0.87               0.89              0.87
#
#            Bagging_train  Bagging_test  Boosting_train  Boosting_test
# ...

# %%
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(LR_train_fpr, LR_train_tpr,color='red',label="LR")
plt.plot(NB_train_fpr, NB_train_tpr,color='green',label="NB")
plt.plot(bag_train_fpr, bag_train_tpr,color='magenta',label="Bag")
plt.plot(KNN_train_fpr, KNN_train_tpr,color='blue',label="KNN")
plt.plot(LDA_train_fpr, LDA_train_tpr,color='black',label="LDA")
plt.plot(ada_train_fpr, ada_train_tpr,color='yellow',label="Ada_Boost")
plt.plot(gbcl_train_fpr, gbcl_train_tpr,color='orange',label="Grad_boost")

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower right')

# %%
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(LR_test_fpr, LR_test_tpr,color='red',label="LR")
plt.plot(NB_test_fpr, NB_test_tpr,color='green',label="NB")
plt.plot(bag_test_fpr, bag_test_tpr,color='magenta',label="Bag")
plt.plot(KNN_test_fpr, KNN_test_tpr,color='blue',label="KNN")
plt.plot(LDA_test_fpr, LDA_test_tpr,color='black',label="LDA")
plt.plot(ada_test_fpr, ada_test_tpr,color='yellow',label="Ada_Boost")
plt.plot(gbcl_test_fpr, gbcl_test_tpr,color='orange',label="Grad_boost")

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower right')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [158], in <cell line: 2>()
#       1 plt.plot([0, 1], [0, 1], linestyle='--')
# ----> 2 plt.plot(LR_test_fpr, LR_test_tpr,color='red',label="LR")
#       3 plt.plot(NB_test_fpr, NB_test_tpr,color='green',label="NB")
#       4 plt.plot(bag_test_fpr, bag_test_tpr,color='magenta',label="Bag")
#
# NameError: name 'LR_test_fpr' is not defined

# %% [markdown]
# # Problem-2 Text Analytics

# %%
import nltk
nltk.download('inaugural')
from nltk.corpus import inaugural
inaugural.fileids()
inaugural.raw('1941-Roosevelt.txt')
inaugural.raw('1961-Kennedy.txt')
inaugural.raw('1973-Nixon.txt')
import pandas as pd
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package inaugural to
# [nltk_data]     C:\Users\91702\AppData\Roaming\nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!

# %% [markdown]
# ##2.1) Find the number of characters, words and sentences for the mentioned documents. (Hint: use .words(), .raw(), .sent() for extracting counts)

# %%
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
len(inaugural.fileids())
# Out:
# 59

# %% [markdown]
# ## 1.President Franklin D. Roosevelt in 1941

# %%
## Number of characters

Roose_raw=inaugural.raw('1941-Roosevelt.txt')
len(inaugural.raw('1941-Roosevelt.txt'))
# Out:
# 7571

# %%
## Number of words

Roose_words=inaugural.words('1941-Roosevelt.txt')
len(inaugural.words('1941-Roosevelt.txt'))
# Out:
# 1536

# %%
## Number of words with split

Roose_words_split = Roose_raw.split()
len(Roose_words_split)
# Out:
# 1360

# %%
Roose_lines=inaugural.sents('1941-Roosevelt.txt')
len(inaugural.sents('1941-Roosevelt.txt'))
# Out:
# 68

# %%
Roose_lower=Roose_raw.lower()
Roose_lower
Roose_lower_words=Roose_lower.split()

# %%
Roose_lower
# Out:
# 'on each national day of inauguration since 1789, the people have renewed their sense of dedication to the united states.\n\nin washington\'s day the task of the people was to create and weld together a nation.\n\nin lincoln\'s day the task of the people was to preserve that nation from disruption from within.\n\nin this day the task of the people is to save that nation and its institutions from disruption from without.\n\nto us there has come a time, in the midst of swift happenings, to pause for a moment and take stock -- to recall what our place in history has been, and to rediscover what we are and what we may be. if we do not, we risk the real peril of inaction.\n\nlives of nations are determined not by the count of years, but by the lifetime of the human spirit. the life of a man is three-score years and ten: a little more, a little less. the life of a nation is the fullness of the measure of its will to live.\n\nthere are men who doubt this. there are men who believe that demo
# ...

# %%
Roose_lower_words
# Out:
# ['on',
#  'each',
#  'national',
#  'day',
#  'of',
#  'inauguration',
#  'since',
#  '1789,',
#  'the',
#  'people',
#  'have',
#  'renewed',
#  'their',
#  'sense',
#  'of',
#  'dedication',
#  'to',
#  'the',
#  'united',
#  'states.',
#  'in',
#  "washington's",
#  'day',
#  'the',
#  'task',
#  'of',
#  'the',
#  'people',
#  'was',
#  'to',
#  'create',
#  'and',
#  'weld',
#  'together',
#  'a',
#  'nation.',
#  'in',
#  "lincoln's",
#  'day',
#  'the',
#  'task',
#  'of',
#  'the',
#  'people',
#  'was',
#  'to',
#  'preserve',
#  'that',
#  'nation',
#  'from',
#  'disruption',
#  'from',
#  'within.',
#  'in',
#  'this',
#  'day',
#  'the',
#  'task',
#  'of',
#  'the',
#  'people',
#  'is',
#  'to',
#  'save',
#  'that',
#  'nation',
#  'and',
#  'its',
#  'institutions',
#  'from',
#  'disruption',
#  'from',
#  'without.',
#  'to',
#  'us',
#  'there',
#  'has',
#  'come',
#  'a',
#  'time,',
#  'in',
#  'the',
#  'midst',
#  'of',
#  'swift',
#  'happenings,',
#  'to',
# ...

# %%
## Stop words
import string
stopwords=nltk.corpus.stopwords.words('english')+list(string.punctuation)
stopwords.extend(["http","bit","bitly","bit ly", "dear", "im", "i'm", "please","us","--","know","let","shall","new"])

# %%
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
## character "--" and words "know","let" were added to the stop word list

# %%
## Stop word removal for president1
filtered_sentence = []
  
for w in Roose_lower_words:
    if w not in stopwords:
        filtered_sentence.append(w)  


print(" ".join(filtered_sentence))
# Out:
# national day inauguration since 1789, people renewed sense dedication united states. washington's day task people create weld together nation. lincoln's day task people preserve nation disruption within. day task people save nation institutions disruption without. come time, midst swift happenings, pause moment take stock recall place history been, rediscover may be. not, risk real peril inaction. lives nations determined count years, lifetime human spirit. life man three-score years ten: little more, little less. life nation fullness measure live. men doubt this. men believe democracy, form government frame life, limited measured kind mystical artificial fate that, unexplained reason, tyranny slavery become surging wave future freedom ebbing tide. americans true. eight years ago, life republic seemed frozen fatalistic terror, proved true. midst shock acted. acted quickly, boldly, decisively. later years living years fruitful years people democracy. brought greater security and, hope
# ...

# %%
filtered_words = []
  
for w in Roose_lower_words:
    if w in stopwords:
        filtered_words.append(w)  


print(",".join(filtered_words))
# Out:
# on,each,of,the,have,their,of,to,the,in,the,of,the,was,to,and,a,in,the,of,the,was,to,that,from,from,in,this,the,of,the,is,to,that,and,its,from,from,to,us,there,has,a,in,the,of,to,for,a,and,--,to,what,our,in,has,and,to,what,we,are,and,what,we,if,we,do,we,the,of,of,are,not,by,the,of,but,by,the,of,the,the,of,a,is,and,a,a,the,of,a,is,the,of,the,of,its,will,to,there,are,who,there,are,who,that,as,a,of,and,a,of,is,or,by,a,of,and,for,some,and,have,the,of,the,--,and,that,is,an,but,we,know,that,this,is,not,when,the,of,this,by,a,we,that,this,is,not,we,were,in,the,of,--,but,we,we,these,have,been,--,for,the,of,this,for,they,have,to,us,i,a,that,are,to,be,in,other,than,most,to,our,and,our,is,this,of,a,which,at,on,through,it,the,of,its,for,has,been,the,of,the,of,the,the,of,the,to,the,of,the,of,is,of,the,of,have,their,to,is,not,we,know,it,because,we,have,it,we,know,it,--,because,it,is,on,the,of,and,in,a,--,an,and,through,by,the,of,a,we,know,it,because,of,all,of,the,of,we,know,it,because,has,an,of,in,t
# ...

# %%
len(filtered_sentence)
# Out:
# 625

# %%
all_words_freq=nltk.FreqDist(filtered_sentence)
all_words_freq
# Out:
# FreqDist({'life': 6, 'people': 5, 'nation': 5, 'human': 5, 'years': 5, 'freedom': 5, 'democracy': 5, 'spirit': 5, 'speaks': 5, 'day': 4, ...})

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud,STOPWORDS

# %%
words = ' '.join(filtered_sentence)

# %%
cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and word != 'RT'
                            ])

# %%
wordcloud = WordCloud(stopwords=STOPWORDS,
                      width=3000,
                      height=2500
                     ).generate(cleaned_word)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 12))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ## President John F. Kennedy in 1961

# %%
Kennedy_raw=inaugural.raw('1961-Kennedy.txt')
Kennedy_raw
# Out:
# 'Vice President Johnson, Mr. Speaker, Mr. Chief Justice, President Eisenhower, Vice President Nixon, President Truman, reverend clergy, fellow citizens, we observe today not a victory of party, but a celebration of freedom -- symbolizing an end, as well as a beginning -- signifying renewal, as well as change. For I have sworn I before you and Almighty God the same solemn oath our forebears l prescribed nearly a century and three quarters ago.\n\nThe world is very different now. For man holds in his mortal hands the power to abolish all forms of human poverty and all forms of human life. And yet the same revolutionary beliefs for which our forebears fought are still at issue around the globe -- the belief that the rights of man come not from the generosity of the state, but from the hand of God.\n\nWe dare not forget today that we are the heirs of that first revolution. Let the word go forth from this time and place, to friend and foe alike, that the torch has been passed to a new gen
# ...

# %%
len(inaugural.raw('1961-Kennedy.txt'))
# Out:
# 7618

# %%
## Number of words

Kennedy_words=inaugural.words('1961-Kennedy.txt')
len(inaugural.words('1961-Kennedy.txt'))
# Out:
# 1546

# %%
## Number of words with spli
Kennedy_words_split = Kennedy_raw.split()
len(Kennedy_words_split)
# Out:
# 1390

# %%
Kennedy_lines=inaugural.sents('1961-Kennedy.txt')
len(inaugural.sents('1961-Kennedy.txt'))
# Out:
# 52

# %%
Kennedy_lower=Kennedy_raw.lower()
Kennedy_lower
Kennedy_lower_words=Kennedy_lower.split()

# %%
Kennedy_lower
# Out:
# 'vice president johnson, mr. speaker, mr. chief justice, president eisenhower, vice president nixon, president truman, reverend clergy, fellow citizens, we observe today not a victory of party, but a celebration of freedom -- symbolizing an end, as well as a beginning -- signifying renewal, as well as change. for i have sworn i before you and almighty god the same solemn oath our forebears l prescribed nearly a century and three quarters ago.\n\nthe world is very different now. for man holds in his mortal hands the power to abolish all forms of human poverty and all forms of human life. and yet the same revolutionary beliefs for which our forebears fought are still at issue around the globe -- the belief that the rights of man come not from the generosity of the state, but from the hand of god.\n\nwe dare not forget today that we are the heirs of that first revolution. let the word go forth from this time and place, to friend and foe alike, that the torch has been passed to a new gen
# ...

# %%
Kennedy_lower_words
# Out:
# ['vice',
#  'president',
#  'johnson,',
#  'mr.',
#  'speaker,',
#  'mr.',
#  'chief',
#  'justice,',
#  'president',
#  'eisenhower,',
#  'vice',
#  'president',
#  'nixon,',
#  'president',
#  'truman,',
#  'reverend',
#  'clergy,',
#  'fellow',
#  'citizens,',
#  'we',
#  'observe',
#  'today',
#  'not',
#  'a',
#  'victory',
#  'of',
#  'party,',
#  'but',
#  'a',
#  'celebration',
#  'of',
#  'freedom',
#  '--',
#  'symbolizing',
#  'an',
#  'end,',
#  'as',
#  'well',
#  'as',
#  'a',
#  'beginning',
#  '--',
#  'signifying',
#  'renewal,',
#  'as',
#  'well',
#  'as',
#  'change.',
#  'for',
#  'i',
#  'have',
#  'sworn',
#  'i',
#  'before',
#  'you',
#  'and',
#  'almighty',
#  'god',
#  'the',
#  'same',
#  'solemn',
#  'oath',
#  'our',
#  'forebears',
#  'l',
#  'prescribed',
#  'nearly',
#  'a',
#  'century',
#  'and',
#  'three',
#  'quarters',
#  'ago.',
#  'the',
#  'world',
#  'is',
#  'very',
#  'different',
#  'now.',
#  'for',
#  'man',
#  'holds',
#  'in',
# ...

# %%
filtered_sentence_K = []
  
for w in Kennedy_lower_words:
    if w not in stopwords:
        filtered_sentence_K.append(w)  


print(",".join(filtered_sentence_K))
# Out:
# vice,president,johnson,,mr.,speaker,,mr.,chief,justice,,president,eisenhower,,vice,president,nixon,,president,truman,,reverend,clergy,,fellow,citizens,,observe,today,victory,party,,celebration,freedom,symbolizing,end,,well,beginning,signifying,renewal,,well,change.,sworn,almighty,god,solemn,oath,forebears,l,prescribed,nearly,century,three,quarters,ago.,world,different,now.,man,holds,mortal,hands,power,abolish,forms,human,poverty,forms,human,life.,yet,revolutionary,beliefs,forebears,fought,still,issue,around,globe,belief,rights,man,come,generosity,state,,hand,god.,dare,forget,today,heirs,first,revolution.,word,go,forth,time,place,,friend,foe,alike,,torch,passed,new,generation,americans,born,century,,tempered,war,,disciplined,hard,bitter,peace,,proud,ancient,heritage,unwilling,witness,permit,slow,undoing,human,rights,nation,always,committed,,committed,today,home,around,world.,every,nation,know,,whether,wishes,well,ill,,pay,price,,bear,burden,,meet,hardship,,support,friend,,oppose,foe,,
# ...

# %%
filtered_words = []
  
for w in Kennedy_lower_words:
    if w in stopwords:
        filtered_words.append(w)  


print(",".join(filtered_words))
# Out:
# we,not,a,of,but,a,of,--,an,as,as,a,--,as,as,for,i,have,i,before,you,and,the,same,our,a,and,the,is,very,for,in,his,the,to,all,of,and,all,of,and,the,same,for,which,our,are,at,the,--,the,that,the,of,not,from,the,of,the,but,from,the,of,we,not,that,we,are,the,of,that,let,the,from,this,and,to,and,that,the,has,been,to,a,of,--,in,this,by,by,a,and,of,our,--,and,to,or,the,of,those,to,which,this,has,been,and,to,which,we,are,at,and,the,let,it,us,or,that,we,shall,any,any,any,any,any,in,to,the,and,the,of,this,we,--,and,to,those,and,we,we,the,of,there,is,we,do,in,a,of,there,is,we,can,do,--,for,we,not,a,at,and,to,those,whom,we,to,the,of,the,we,our,that,of,shall,not,have,to,be,by,a,more,we,shall,not,to,them,our,but,we,shall,to,them,their,own,--,and,to,in,the,those,who,by,the,of,the,up,to,those,in,the,and,the,to,the,of,we,our,to,them,for,is,--,not,because,the,be,doing,not,because,we,their,but,because,it,is,if,a,the,who,are,it,the,few,who,are,to,our,of,our,we,a,--,to,our,into,--,in,a,for,--,to,and,in,o
# ...

# %%
len(filtered_sentence_K)
# Out:
# 672

# %%
all_words_freq=nltk.FreqDist(filtered_sentence_K)
all_words_freq
# Out:
# FreqDist({'new': 7, 'pledge': 7, 'sides': 7, 'ask': 5, 'president': 4, 'fellow': 4, 'freedom': 4, 'power': 4, 'first': 4, 'always': 4, ...})

# %%
words = ' '.join(filtered_sentence_K)

# %%
cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and word != 'RT'
                            ])

# %%
wordcloud = WordCloud(stopwords=STOPWORDS,
                      width=3000,
                      height=2500
                     ).generate(cleaned_word)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 12))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 3.President Richard Nixon in 1973

# %%
Nixon_raw=inaugural.raw('1973-Nixon.txt')
Nixon_raw
# Out:
# 'Mr. Vice President, Mr. Speaker, Mr. Chief Justice, Senator Cook, Mrs. Eisenhower, and my fellow citizens of this great and good country we share together:\n\nWhen we met here four years ago, America was bleak in spirit, depressed by the prospect of seemingly endless war abroad and of destructive conflict at home.\n\nAs we meet here today, we stand on the threshold of a new era of peace in the world.\n\nThe central question before us is: How shall we use that peace? Let us resolve that this era we are about to enter will not be what other postwar periods have so often been: a time of retreat and isolation that leads to stagnation at home and invites new danger abroad.\n\nLet us resolve that this will be what it can become: a time of great responsibilities greatly borne, in which we renew the spirit and the promise of America as we enter our third century as a nation.\n\nThis past year saw far-reaching results from our new policies for peace. By continuing to revitalize our tradition
# ...

# %%
len(inaugural.raw('1973-Nixon.txt'))
# Out:
# 9991

# %%
## Number of words

Nixon_words=inaugural.words('1973-Nixon.txt')
len(inaugural.words('1973-Nixon.txt'))
# Out:
# 2028

# %%
## Number of words with split

Nixon_words_split = Nixon_raw.split()
len(Nixon_words_split)
# Out:
# 1819

# %%
Nixon_sent=inaugural.sents('1973-Nixon.txt')
len(Nixon_sent)
# Out:
# 69

# %%
Nixon_lower=Nixon_raw.lower()
Nixon_lower
Nixon_lower_words=Nixon_lower.split()

# %%
Nixon_lower
# Out:
# 'mr. vice president, mr. speaker, mr. chief justice, senator cook, mrs. eisenhower, and my fellow citizens of this great and good country we share together:\n\nwhen we met here four years ago, america was bleak in spirit, depressed by the prospect of seemingly endless war abroad and of destructive conflict at home.\n\nas we meet here today, we stand on the threshold of a new era of peace in the world.\n\nthe central question before us is: how shall we use that peace? let us resolve that this era we are about to enter will not be what other postwar periods have so often been: a time of retreat and isolation that leads to stagnation at home and invites new danger abroad.\n\nlet us resolve that this will be what it can become: a time of great responsibilities greatly borne, in which we renew the spirit and the promise of america as we enter our third century as a nation.\n\nthis past year saw far-reaching results from our new policies for peace. by continuing to revitalize our tradition
# ...

# %%
Nixon_lower_words
# Out:
# ['mr.',
#  'vice',
#  'president,',
#  'mr.',
#  'speaker,',
#  'mr.',
#  'chief',
#  'justice,',
#  'senator',
#  'cook,',
#  'mrs.',
#  'eisenhower,',
#  'and',
#  'my',
#  'fellow',
#  'citizens',
#  'of',
#  'this',
#  'great',
#  'and',
#  'good',
#  'country',
#  'we',
#  'share',
#  'together:',
#  'when',
#  'we',
#  'met',
#  'here',
#  'four',
#  'years',
#  'ago,',
#  'america',
#  'was',
#  'bleak',
#  'in',
#  'spirit,',
#  'depressed',
#  'by',
#  'the',
#  'prospect',
#  'of',
#  'seemingly',
#  'endless',
#  'war',
#  'abroad',
#  'and',
#  'of',
#  'destructive',
#  'conflict',
#  'at',
#  'home.',
#  'as',
#  'we',
#  'meet',
#  'here',
#  'today,',
#  'we',
#  'stand',
#  'on',
#  'the',
#  'threshold',
#  'of',
#  'a',
#  'new',
#  'era',
#  'of',
#  'peace',
#  'in',
#  'the',
#  'world.',
#  'the',
#  'central',
#  'question',
#  'before',
#  'us',
#  'is:',
#  'how',
#  'shall',
#  'we',
#  'use',
#  'that',
#  'peace?',
#  'let',
#  'us',
#  'resolve',
# ...

# %%
filtered_sentence_N = []
  
for w in Nixon_lower_words:
    if w not in stopwords:
        filtered_sentence_N.append(w)  


print(",".join(filtered_sentence_N))
# Out:
# mr.,vice,president,,mr.,speaker,,mr.,chief,justice,,senator,cook,,mrs.,eisenhower,,fellow,citizens,great,good,country,share,together:,met,four,years,ago,,america,bleak,spirit,,depressed,prospect,seemingly,endless,war,abroad,destructive,conflict,home.,meet,today,,stand,threshold,era,peace,world.,central,question,is:,use,peace?,resolve,era,enter,postwar,periods,often,been:,time,retreat,isolation,leads,stagnation,home,invites,danger,abroad.,resolve,become:,time,great,responsibilities,greatly,borne,,renew,spirit,promise,america,enter,third,century,nation.,past,year,saw,far-reaching,results,policies,peace.,continuing,revitalize,traditional,friendships,,missions,peking,moscow,,able,establish,base,durable,pattern,relationships,among,nations,world.,america's,bold,initiatives,,1972,long,remembered,year,greatest,progress,since,end,world,war,ii,toward,lasting,peace,world.,peace,seek,world,flimsy,peace,merely,interlude,wars,,peace,endure,generations,come.,important,understand,necessity,limitatio
# ...

# %%
filtered_words = []
  
for w in Nixon_lower_words:
    if w in stopwords:
        filtered_words.append(w)  


print(",".join(filtered_words))
# Out:
# and,my,of,this,and,we,when,we,here,was,in,by,the,of,and,of,at,as,we,here,we,on,the,of,a,new,of,in,the,the,before,us,how,shall,we,that,let,us,that,this,we,are,about,to,will,not,be,what,other,have,so,a,of,and,that,to,at,and,new,let,us,that,this,will,be,what,it,can,a,of,in,which,we,the,and,the,of,as,we,our,as,a,this,from,our,new,for,by,to,our,and,by,our,to,and,to,we,were,to,the,for,a,new,and,more,of,the,of,the,because,of,will,be,as,the,of,the,the,of,a,in,the,the,we,in,the,is,not,the,which,is,an,between,but,a,which,can,for,to,it,is,that,we,both,the,and,the,of,in,that,we,in,to,the,there,will,be,no,we,in,to,there,will,be,no,but,let,us,the,new,of,as,a,of,the,new,we,have,over,these,we,shall,our,we,shall,the,that,no,has,the,to,its,will,or,on,by,we,shall,in,this,of,to,for,the,of,and,to,the,of,between,the,we,shall,do,our,in,and,in,the,but,we,shall,to,do,their,the,has,when,will,other,our,or,other,our,or,to,the,of,other,how,to,their,own,just,as,we,the,of,each,to,its,own,we,the,of,each,to,its,own,
# ...

# %%
all_words_freq=nltk.FreqDist(filtered_sentence_N)
all_words_freq
# Out:
# FreqDist({'peace': 11, 'great': 9, 'america': 9, 'world.': 8, "america's": 8, 'policies': 7, 'world': 7, 'make': 7, 'every': 7, 'better': 7, ...})

# %%
len(filtered_sentence_N)
# Out:
# 775

# %%
words = ' '.join(filtered_sentence_N)

# %%
cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and word != 'RT'
                            ])

# %%
wordcloud = WordCloud(stopwords=STOPWORDS,
                      width=3000,
                      height=2500
                     ).generate(cleaned_word)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 12))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
